# %% [markdown]
# # Quantitative Momentum Strategy V2
#
# Nessa segunda versão vou usar o retorno não apenas anual, como no último mês, no último trimestre, semestre e último ano.

# %%
import numpy as np
import pandas as pd
import math
import datetime
from scipy import stats
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
tickets = pd.read_csv('./data/BOVA11_holdings.csv')
tickets = tickets['Código']
tickets
# Out:
# 0      VALE3
# 1      ITUB4
# 2      PETR4
# 3      BBDC4
# 4      B3SA3
#        ...
# 76     HGTX3
# 77     ECOR3
# 78    CVCB11
# 79      XBZ0
# 80
# Name: Código, Length: 81, dtype: object

# %%
columns = ['Ticker', 'Price', 'Number of Shares to Buy', 
           'One-Year Price Return', 'One-Year Return Percentile', 
           'Six-Month Price Return', 'Six-Month Return Percentile', 
           'Three-Month Price Return', 'Three-Month Return Percentile', 
           'One-Month Price Return', 'One-Month Return Percentile', 'HQM Score']
stocks = pd.DataFrame(columns = columns)
today = datetime.datetime.today().strftime('%Y-%m-%d')
last_year = datetime.datetime.now() - datetime.timedelta(days=365)
last_year = last_year.strftime('%Y-%m-%d')

for ticket in tickets:
    try:
        data = pdr.get_data_yahoo(ticket+'.SA', start=last_year, end=today)
        close = list(data['Close'])
        size = len(close)
        one_year_return = (close[size-1]-close[0])/close[0]
        six_month_return = (close[math.floor(size/2)-1]-close[0])/close[0]
        three_month_return = (close[math.floor(size/4)-1]-close[0])/close[0]
        one_month_return = (close[math.floor(size/12)-1]-close[0])/close[0]
        price = close[size-1]

        stocks = stocks.append(pd.Series([ticket, 
                                        price, 'N/A', 
                                        one_year_return, 'N/A', 
                                        six_month_return, 'N/A', 
                                        three_month_return, 'N/A', 
                                        one_month_return, 'N/A', 
                                        'N/A'], 
                                        index = columns), 
                                ignore_index = True)
    except:
        pass
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BRL.SA: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CVCB11.SA: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - XBZ0.SA: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - .SA: No data found, symbol may be delisted

# %%
stocks_copy = stocks.copy()

# %%
deltas = ['One-Year', 'Six-Month', 'Three-Month', 'One-Month']

for i in range(stocks_copy.shape[0]):
    for delta in deltas:
        col = '{} Return Percentile'.format(delta)
        _col = '{} Price Return'.format(delta)
        stocks_copy.loc[i, col] = stats.percentileofscore(stocks_copy[_col], stocks_copy.loc[i, _col])/100

# %%
from statistics import mean

for i in range(stocks_copy.shape[0]):
    momentuns = []
    for delta in deltas:
        col = '{} Return Percentile'.format(delta)
        momentuns.append(stocks_copy.loc[i, col])
    stocks_copy.loc[i, 'HQM Score'] = mean(momentuns)

# %%
stocks_copy.sort_values(by='HQM Score', ascending=False)
stocks_copy = stocks_copy[:25]

# %%
stocks_copy
# Out:
#    Ticker      Price Number of Shares to Buy  One-Year Price Return  \
# 0   VALE3  82.269997                     N/A               0.599339
# 1   ITUB4  30.250000                     N/A              -0.172367
# 2   PETR4  27.410000                     N/A              -0.092685
# 3   BBDC4  25.629999                     N/A              -0.259249
# 4   B3SA3  58.529999                     N/A               0.228332
# 5   PETR3  28.100000                     N/A              -0.128141
# 6   ABEV3  14.720000                     N/A              -0.201735
# 7   MGLU3  23.719999                     N/A               1.069357
# 8   ITSA4  11.170000                     N/A              -0.183480
# 9   WEGE3  71.970001                     N/A               1.255406
# 10  BBAS3  35.669998                     N/A              -0.266351
# 11  GNDI3  74.389999                     N/A               0.266428
# 12  NTCO3  49.400002                     N/A               0.343852
# 13  RENT3  66.800003                     N/A               0.553832
# 14  SUZB3  52.680000                     N/A               0.394389
# 15  JBSS3  22.969999                     N/A              -0.134188
# 16  LREN3  45.990002                     N/A              -0.130624
# 17  BBDC3  22.889999                     N/A              -0.285357
# 18  VVAR3  17.730000                     N/A               0.733138
# 19  RAIL3  20.840000                     N/A              -0.173016
# 20  RADL3  24.700001                     N/A               0.201479
# 21  BRDT3  21.219999                     N/A              -0.203752
# 22  UGPA3  21.950001                     N/A               0.026661
# 23  EQTL3  21.910000                     N/A              -0.000456
# 24  GGBR4  23.049999                     N/A               0.341676
#
#    One-Year Return Percentile  Six-Month Price Return  \
# 0                    0.909091                0.069013
# 1                    0.350649               -0.239398
# 2                    0.441558               -0.281033
# 3                    0.181818               -0.336705
# 4                    0.766234                0.071773
# 5                    0.402597               -0.295997
# 6                    0.285714               -0.223427
# 7                    0.974026                0.360524
# 8                    0.324675               -0.242690
# 9                           1                0.435600
# 10                   0.168831               -0.263883
# 11                   0.792208                0.083759
# 12                   0.844156                0.096572
# 13                   0.896104               -0.002105
# 14                   0.883117                0.010323
# 15                   0.376623               -0.168489
# 16                    0.38961               -0.133837
# 17                   0.142857               -0.337808
# 18                   0.948052                0.463343
# 19                   0.337662               -0.035318
# 20                   0.753247                0.074521
# 21                   0.272727               -0.121576
# 22                   0.688312               -0.098690
# 23                   0.623377               -0.006843
# 24                   0.831169               -0.129220
#
#    Six-Month Return Percentile  Three-Month Price Return  \
# 0                     0.818182                 -0.208009
# 1                     0.285714                 -0.283995
# 2                     0.207792                 -0.475339
# 3                     0.155844                 -0.277746
# 4                     0.831169                 -0.107030
# 5                     0.168831                 -0.492088
# 6                     0.298701                 -0.254338
# 7                     0.961039                 -0.060414
# 8                     0.272727                 -0.239766
# 9                     0.974026                  0.313381
# 10                    0.220779                 -0.185315
# 11                     0.87013                 -0.165815
# 12                    0.909091                 -0.314472
# 13                    0.727273                 -0.093753
# 14                    0.766234                 -0.061408
# 15                    0.363636                 -0.284584
# 16                    0.441558                 -0.109830
# 17                    0.142857                 -0.314081
# 18                    0.987013                  0.075269
# 19                    0.662338                 -0.320635
# 20                    0.844156                  0.118786
# 21                    0.480519                 -0.148593
# 22                    0.558442                 -0.220299
# 23                    0.701299                 -0.023723
# 24                    0.454545                 -0.261350
#
#    Three-Month Return Percentile  One-Month Price Return  \
# 0                       0.428571                0.036159
# 1                       0.246753               -0.044870
# 2                      0.0779221                0.006289
# 3                        0.25974                0.013584
# 4                       0.701299               -0.062959
# 5                      0.0649351                0.000000
# 6                       0.298701                0.020607
# 7                       0.818182                0.135878
# 8                       0.376623               -0.017544
# 9                              1                0.044187
# 10                      0.506494                0.050185
# 11                      0.545455                0.163943
# 12                      0.168831                0.248096
# 13                      0.766234                0.135600
# 14                      0.805195                0.139227
# 15                      0.233766                0.067094
# 16                      0.688312                0.076560
# 17                      0.181818                0.037465
# 18                      0.948052                0.139785
# 19                      0.155844                0.028968
# 20                      0.987013                0.102345
# 21                      0.597403                0.054034
# 22                      0.402597                0.176333
# 23                      0.857143                0.077555
# 24                      0.285714                0.202561
#
#    One-Month Return Percentile HQM Score
# 0                     0.272727  0.607143
# 1                    0.0649351  0.237013
# 2                     0.181818  0.227273
# 3                     0.207792  0.201299
# 4                     0.038961  0.584416
# 5                     0.149351  0.196429
# 6                     0.220779  0.275974
# 7                     0.792208  0.886364
# 8                    0.0909091  0.266234
# 9                     0.337662  0.827922
# 10                    0.363636  0.314935
# 11                    0.883117  0.772727
# 12                    0.987013  0.727273
# 13                    0.779221  0.792208
# 14                    0.818182  0.818182
# 15                    0.428571  0.350649
# 16                    0.493506  0.503247
# 17                    0.285714  0.188312
# 18                    0.831169  0.928571
# 19                    0.246753  0.350649
# 20                    0.688312  0.818182
# 21                     0.38961  0.435065
# 22                    0.896104  0.636364
# 23                    0.506494  0.672078
# 24                    0.935065  0.626623

# %%
portfolio_size = 1e8
position_size = portfolio_size/stocks_copy.shape[0]
for i in range(stocks_copy.shape[0]):
    stocks_copy.loc[i, 'Number of Shares to Buy'] = math.floor(position_size/stocks_copy['Price'][i])
# Out:
# /home/ne0/.local/lib/python3.8/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
stocks_copy
# Out:
#    Ticker      Price Number of Shares to Buy  One-Year Price Return  \
# 0   VALE3  82.269997                   48620               0.599339
# 1   ITUB4  30.250000                  132231              -0.172367
# 2   PETR4  27.410000                  145932              -0.092685
# 3   BBDC4  25.629999                  156067              -0.259249
# 4   B3SA3  58.529999                   68341               0.228332
# 5   PETR3  28.100000                  142348              -0.128141
# 6   ABEV3  14.720000                  271739              -0.201735
# 7   MGLU3  23.719999                  168634               1.069357
# 8   ITSA4  11.170000                  358102              -0.183480
# 9   WEGE3  71.970001                   55578               1.255406
# 10  BBAS3  35.669998                  112139              -0.266351
# 11  GNDI3  74.389999                   53770               0.266428
# 12  NTCO3  49.400002                   80971               0.343852
# 13  RENT3  66.800003                   59880               0.553832
# 14  SUZB3  52.680000                   75930               0.394389
# 15  JBSS3  22.969999                  174140              -0.134188
# 16  LREN3  45.990002                   86975              -0.130624
# 17  BBDC3  22.889999                  174748              -0.285357
# 18  VVAR3  17.730000                  225606               0.733138
# 19  RAIL3  20.840000                  191938              -0.173016
# 20  RADL3  24.700001                  161943               0.201479
# 21  BRDT3  21.219999                  188501              -0.203752
# 22  UGPA3  21.950001                  182232               0.026661
# 23  EQTL3  21.910000                  182565              -0.000456
# 24  GGBR4  23.049999                  173535               0.341676
#
#    One-Year Return Percentile  Six-Month Price Return  \
# 0                    0.909091                0.069013
# 1                    0.350649               -0.239398
# 2                    0.441558               -0.281033
# 3                    0.181818               -0.336705
# 4                    0.766234                0.071773
# 5                    0.402597               -0.295997
# 6                    0.285714               -0.223427
# 7                    0.974026                0.360524
# 8                    0.324675               -0.242690
# 9                           1                0.435600
# 10                   0.168831               -0.263883
# 11                   0.792208                0.083759
# 12                   0.844156                0.096572
# 13                   0.896104               -0.002105
# 14                   0.883117                0.010323
# 15                   0.376623               -0.168489
# 16                    0.38961               -0.133837
# 17                   0.142857               -0.337808
# 18                   0.948052                0.463343
# 19                   0.337662               -0.035318
# 20                   0.753247                0.074521
# 21                   0.272727               -0.121576
# 22                   0.688312               -0.098690
# 23                   0.623377               -0.006843
# 24                   0.831169               -0.129220
#
#    Six-Month Return Percentile  Three-Month Price Return  \
# 0                     0.818182                 -0.208009
# 1                     0.285714                 -0.283995
# 2                     0.207792                 -0.475339
# 3                     0.155844                 -0.277746
# 4                     0.831169                 -0.107030
# 5                     0.168831                 -0.492088
# 6                     0.298701                 -0.254338
# 7                     0.961039                 -0.060414
# 8                     0.272727                 -0.239766
# 9                     0.974026                  0.313381
# 10                    0.220779                 -0.185315
# 11                     0.87013                 -0.165815
# 12                    0.909091                 -0.314472
# 13                    0.727273                 -0.093753
# 14                    0.766234                 -0.061408
# 15                    0.363636                 -0.284584
# 16                    0.441558                 -0.109830
# 17                    0.142857                 -0.314081
# 18                    0.987013                  0.075269
# 19                    0.662338                 -0.320635
# 20                    0.844156                  0.118786
# 21                    0.480519                 -0.148593
# 22                    0.558442                 -0.220299
# 23                    0.701299                 -0.023723
# 24                    0.454545                 -0.261350
#
#    Three-Month Return Percentile  One-Month Price Return  \
# 0                       0.428571                0.036159
# 1                       0.246753               -0.044870
# 2                      0.0779221                0.006289
# 3                        0.25974                0.013584
# 4                       0.701299               -0.062959
# 5                      0.0649351                0.000000
# 6                       0.298701                0.020607
# 7                       0.818182                0.135878
# 8                       0.376623               -0.017544
# 9                              1                0.044187
# 10                      0.506494                0.050185
# 11                      0.545455                0.163943
# 12                      0.168831                0.248096
# 13                      0.766234                0.135600
# 14                      0.805195                0.139227
# 15                      0.233766                0.067094
# 16                      0.688312                0.076560
# 17                      0.181818                0.037465
# 18                      0.948052                0.139785
# 19                      0.155844                0.028968
# 20                      0.987013                0.102345
# 21                      0.597403                0.054034
# 22                      0.402597                0.176333
# 23                      0.857143                0.077555
# 24                      0.285714                0.202561
#
#    One-Month Return Percentile HQM Score
# 0                     0.272727  0.607143
# 1                    0.0649351  0.237013
# 2                     0.181818  0.227273
# 3                     0.207792  0.201299
# 4                     0.038961  0.584416
# 5                     0.149351  0.196429
# 6                     0.220779  0.275974
# 7                     0.792208  0.886364
# 8                    0.0909091  0.266234
# 9                     0.337662  0.827922
# 10                    0.363636  0.314935
# 11                    0.883117  0.772727
# 12                    0.987013  0.727273
# 13                    0.779221  0.792208
# 14                    0.818182  0.818182
# 15                    0.428571  0.350649
# 16                    0.493506  0.503247
# 17                    0.285714  0.188312
# 18                    0.831169  0.928571
# 19                    0.246753  0.350649
# 20                    0.688312  0.818182
# 21                     0.38961  0.435065
# 22                    0.896104  0.636364
# 23                    0.506494  0.672078
# 24                    0.935065  0.626623
